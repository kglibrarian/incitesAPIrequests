# %%
# Dependencies
import requests
import json
import pandas as pd
import numpy as np
import re
import io
from config import api_key_inCites
from config import api_key_WOS
from collections import OrderedDict
from pandas.io.json import json_normalize  
import base64
import xmltodict

# %%
##WOS Resources:
#https://github.com/Jask-Code/Research-Analytics/blob/master/WOS_API_Automation.ipynb
#http://help.incites.clarivate.com/wosWebServicesExpanded/WebServicesExpandedOverviewGroup/Introduction/ServiceEndpointAddresses.html
#http://search.webofknowledge.com/esti/wokmws/ws/WokSearch
#http://help.incites.clarivate.com/wosWebServicesExpanded/appendix1Group/wosfieldNameTable.html
#https://github.com/langner/wok_search

##InCites Resources: 
#https://clarivate.com/webofsciencegroup/solutions/xml-and-apis/
#https://developer.clarivate.com/help
#https://api.clarivate.com/api/incites/DocumentLevelMetricsByUT/json
#https://github.com/Clarivate-SAR/incites-retrieve

# %%
## Clarivate Analytics InCites API Request

url = "https://api.clarivate.com/api/incites/DocumentLevelMetricsByUT/json"

headers = {
     'X-ApiKey': api_key_inCites,
     'Accept':'application/json'
}



parameters = {
     "UT": "000492801600048"       
   
}

response = requests.get(url, headers=headers, params=parameters)


print(response.url)
print(response.status_code)

response_json = response.json()
print(json.dumps(response_json, indent=4, sort_keys=True))

# %%
##Clarivate Analytics Web of SCience (WOS) API Request

BATCH_SIZE = 50
query = "UT=000492801600048"
databasename = 'WOS'

headers = {
     'X-ApiKey': api_key_WOS,
     'Accept':'application/json'
     
}


parameters = {
   "databaseId": databasename,
    "usrQuery": query,
    "count": BATCH_SIZE,
    'firstRecord' : 1
    
}


    # wos returns the most recent paper on top so it's alright to just grab 1 record
url = 'https://api.clarivate.com/api/wos/'
response = requests.get(url, headers=headers, params=parameters)
  
#addresses = response.json()['Data']['Records']['records']['REC'][0]
    
print(response.url)
print(response.status_code)
response_json = response.json()
print(json.dumps(response_json, indent=4, sort_keys=True))
# Out:
# https://api.clarivate.com/api/wos/?databaseId=WOS&usrQuery=UT%3D000492801600048&count=50&firstRecord=1
# 200
# {
#     "Data": {
#         "Records": {
#             "records": {
#                 "REC": [
#                     {
#                         "UID": "WOS:000492801600048",
#                         "dynamic_data": {
#                             "citation_related": {
#                                 "tc_list": {
#                                     "silo_tc": {
#                                         "coll_id": "WOS",
#                                         "local_count": 0
#                                     }
#                                 }
#                             },
#                             "cluster_related": {
#                                 "identifiers": {
#                                     "identifier": [
#                                         {
#                                             "type": "issn",
#                                             "value": "1936-0851"
#                                         },
#                                         {
#                                             "type": "eissn",
#                                             "value": "1936-086X"
#                                         },
#                                         {
#                                             "type": "doi",
#                                             "value": "10.1021/acsnano.9b04752"
#                                         },
#                                         {
#                                             "type": "pmid",
#                                             "value": "MEDLINE:31513370"
#                                         }
#                                     ]
#                                 }
#                             }
#                         },
#                         "r_id_disclaimer": "ResearcherID data provided by Clarivate Analytics",
#                         "static_data": {
#                             "fullrecord_metadata": {
#                                 "abstracts": {
#                                     "abstract": {
#                                         "abstract_text": {
#                                             "count": 1,
#                                             "p": "Label-free in situ X-ray scattering from protein spherical nucleic acids (Pro-SNAs, consisting of protein cores densely functionalized with covalently bound DNA) was used to elucidate the enzymatic reaction pathway for the DNase I-induced degradation of DNA. Time-course small-angle X-ray scattering (SAXS) and gel electrophoresis reveal a two-state system with time-dependent populations of intact and fully degraded DNA in the Pro-SNAs. SAXS shows that in the fully degraded state, the DNA strands forming the outer shell of the Pro- SNA were completely digested. SAXS analysis of reactions with different Pro-SNA concentrations reveals a reaction pathway characterized by a slow, rate determining DNase I-Pro-SNA association, followed by rapid DNA hydrolysis. Molecular dynamics (MD) simulations provide the distributions of monovalent and divalent ions around the Pro-SNA, relevant to the activity of DNase I. Taken together, in situ SAXS in conjunction with MD simulations yield key mechanistic and structural insights into the interaction of DNA with DNase I. The approach presented here should prove invaluable in probing other enzyme-catalyzed reactions on the nanoscale."
#                                         }
#                                     },
#                                     "count": 1
#                                 },
#                                 "addresses": {
#                                     "address_name": [
#                                         {
#                                             "address_spec": {
#                                                 "addr_no": 1,
#                                                 "city": "Evanston",
#                                                 "country": "USA",
#                                                 "full_address": "Northwestern Univ, Appl Phys Program, Evanston, IL 60208 USA",
#                                                 "organizations": {
#                                                     "count": 2,
#                                                     "organization": [
#                                                         "Northwestern Univ",
#                                                         {
#                                                             "content": "Northwestern University",
#                                                             "pref": "Y"
#                                                         }
#                                                     ]
#                                                 },
#                                                 "state": "IL",
#                                                 "suborganizations": {
#                                                     "count": 1,
#                                                     "suborganization": "Appl Phys Program"
#                                                 },
#                                                 "zip": {
#                                                     "content": 60208,
#                                                     "location": "AP"
#                                                 }
#                                             },
#                                             "names": {
#                                                 "count": 4,
#                                                 "name": [
#                                                     {
#                                                         "addr_no": 1,
#                                                         "daisng_id": 22345515,
#                                                         "display_name": "Krishnamoorthy, Kurinji",
#                                                         "first_name": "Kurinji",
#                                                         "full_name": "Krishnamoorthy, Kurinji",
#                                                         "last_name": "Krishnamoorthy",
#                                                         "role": "author",
#                                                         "seq_no": 1,
#                                                         "wos_standard": "Krishnamoorthy, K"
#                                                     },
#                                                     {
#                                                         "addr_no": 1,
#                                                         "daisng_id": 31118905,
#                                                         "display_name": "Ehlen, Ali",
#                                                         "first_name": "Ali",
#                                                         "full_name": "Ehlen, Ali",
#                                                         "last_name": "Ehlen",
#                                                         "role": "author",
#                                                         "seq_no": 3,
#                                                         "wos_standard": "Ehlen, A"
#                                                     },
#                                                     {
#                                                         "addr_no": 1,
#                                                         "daisng_id": 31445516,
#                                                         "display_name": "de la Cruz, Monica Olvera",
#                                                         "first_name": "Monica Olvera",
#                                                         "full_name": "de la Cruz, Monica Olvera",
#                                                         "last_name": "de la Cruz",
#                                                         "reprint": "Y",
#                                                         "role": "author",
#                                                         "seq_no": 6,
#                                                         "wos_standard": "de la Cruz, MO"
#                                                     },
#                                                     {
#                                                         "addr_no": 1,
#                                                         "daisng_id": 30415168,
#                                                         "display_name": "Bedzyk, Michael J.",
#                                                         "first_name": "Michael J.",
#                                                         "full_name": "Bedzyk, Michael J.",
#                                                         "last_name": "Bedzyk",
#                                                         "reprint": "Y",
#                                                         "role": "author",
#                                                         "seq_no": 7,
#                                                         "wos_standard": "Bedzyk, MJ"
#                                                     }
#                                                 ]
#                                             }
#                                         },
#                                         {
#                                             "address_spec": {
#                                                 "addr_no": 2,
#                                                 "city": "Evanston",
#                                                 "country": "USA",
#                                                 "full_address": "Northwestern Univ, Dept Mat Sci & Engn, Evanston, IL 60208 USA",
#                                                 "organizations": {
#                                                     "count": 2,
#                                                     "organization": [
#                                                         "Northwestern Univ",
#                                                         {
#                                                             "content": "Northwestern University",
#                                                             "pref": "Y"
#                                                         }
#                                                     ]
#                                                 },
#                                                 "state": "IL",
#                                                 "suborganizations": {
#                                                     "count": 1,
#                                                     "suborganization": "Dept Mat Sci & Engn"
#                                                 },
#                                                 "zip": {
#                                                     "content": 60208,
#                                                     "location": "AP"
#                                                 }
#                                             },
#                                             "names": {
#                                                 "count": 5,
#                                                 "name": [
#                                                     {
#                                                         "addr_no": 2,
#                                                         "daisng_id": 1159545,
#                                                         "display_name": "Kewalramani, Sumit",
#                                                         "first_name": "Sumit",
#                                                         "full_name": "Kewalramani, Sumit",
#                                                         "last_name": "Kewalramani",
#                                                         "role": "author",
#                                                         "seq_no": 2,
#                                                         "wos_standard": "Kewalramani, S"
#                                                     },
#                                                     {
#                                                         "addr_no": 2,
#                                                         "daisng_id": 4419377,
#                                                         "display_name": "Moreau, Liane M.",
#                                                         "first_name": "Liane M.",
#                                                         "full_name": "Moreau, Liane M.",
#                                                         "last_name": "Moreau",
#                                                         "role": "author",
#                                                         "seq_no": 4,
#                                                         "wos_standard": "Moreau, LM"
#                                                     },
#                                                     {
#                                                         "addr_no": 2,
#                                                         "daisng_id": 31444953,
#                                                         "display_name": "Mirkin, Chad A.",
#                                                         "first_name": "Chad A.",
#                                                         "full_name": "Mirkin, Chad A.",
#                                                         "last_name": "Mirkin",
#                                                         "reprint": "Y",
#                                                         "role": "author",
#                                                         "seq_no": 5,
#                                                         "wos_standard": "Mirkin, CA"
#                                                     },
#                                                     {
#                                                         "addr_no": 2,
#                                                         "daisng_id": 31445516,
#                                                         "display_name": "de la Cruz, Monica Olvera",
#                                                         "first_name": "Monica Olvera",
#                                                         "full_name": "de la Cruz, Monica Olvera",
#                                                         "last_name": "de la Cruz",
#                                                         "reprint": "Y",
#                                                         "role": "author",
#                                                         "seq_no": 6,
#                                                         "wos_standard": "de la Cruz, MO"
#                                                     },
#                                                     {
#                                                         "addr_no": 2,
#                                                         "daisng_id": 30415168,
#                                                         "display_name": "Bedzyk, Michael J.",
#                                                         "first_name": "Michael J.",
#                                                         "full_name": "Bedzyk, Michael J.",
#                                                         "last_name": "Bedzyk",
#                                                         "reprint": "Y",
#                                                         "role": "author",
#                                                         "seq_no": 7,
#                                                         "wos_standard": "Bedzyk, MJ"
#                                                     }
#                                                 ]
#                                             }
#                                         },
#                                         {
#                                             "address_spec": {
#                                                 "addr_no": 3,
#                                                 "city": "Evanston",
#                                                 "country": "USA",
#                                                 "full_address": "Northwestern Univ, Dept Chem, Evanston, IL 60208 USA",
#                                                 "organizations": {
#                                                     "count": 2,
#                                                     "organization": [
#                                                         "Northwestern Univ",
#                                                         {
#                                                             "content": "Northwestern University",
#                                                             "pref": "Y"
#                                                         }
#                                                     ]
#                                                 },
#                                                 "state": "IL",
#                                                 "suborganizations": {
#                                                     "count": 1,
#                                                     "suborganization": "Dept Chem"
#                                                 },
#                                                 "zip": {
#                                                     "content": 60208,
#                                                     "location": "AP"
#                                                 }
#                                             },
#                                             "names": {
#                                                 "count": 2,
#                                                 "name": [
#                                                     {
#                                                         "addr_no": 3,
#                                                         "daisng_id": 31444953,
#                                                         "display_name": "Mirkin, Chad A.",
#                                                         "first_name": "Chad A.",
#                                                         "full_name": "Mirkin, Chad A.",
#                                                         "last_name": "Mirkin",
#                                                         "reprint": "Y",
#                                                         "role": "author",
#                                                         "seq_no": 5,
#                                                         "wos_standard": "Mirkin, CA"
#                                                     },
#                                                     {
#                                                         "addr_no": 3,
#                                                         "daisng_id": 31445516,
#                                                         "display_name": "de la Cruz, Monica Olvera",
#                                                         "first_name": "Monica Olvera",
#                                                         "full_name": "de la Cruz, Monica Olvera",
#                                                         "last_name": "de la Cruz",
#                                                         "reprint": "Y",
#                                                         "role": "author",
#                                                         "seq_no": 6,
#                                                         "wos_standard": "de la Cruz, MO"
#                                                     }
#                                                 ]
#                                             }
#                                         },
#                                         {
#                                             "address_spec": {
#                                                 "addr_no": 4,
#                                                 "city": "Evanston",
#                                                 "country": "USA",
#                                                 "full_address": "Northwestern Univ, Dept Phys & Astron, Evanston, IL 60208 USA",
#                                                 "organizations": {
#                                                     "count": 2,
#                                                     "organization": [
#                                                         "Northwestern Univ",
#                                                         {
#                                                             "content": "Northwestern University",
#                                                             "pref": "Y"
#                                                         }
#                                                     ]
#                                                 },
#                                                 "state": "IL",
#                                                 "suborganizations": {
#                                                     "count": 1,
#                                                     "suborganization": "Dept Phys & Astron"
#                                                 },
#                                                 "zip": {
#                                                     "content": 60208,
#                                                     "location": "AP"
#                                                 }
#                                             },
#                                             "names": {
#                                                 "count": 2,
#                                                 "name": [
#                                                     {
#                                                         "addr_no": 4,
#                                                         "daisng_id": 31445516,
#                                                         "display_name": "de la Cruz, Monica Olvera",
#                                                         "first_name": "Monica Olvera",
#                                                         "full_name": "de la Cruz, Monica Olvera",
#                                                         "last_name": "de la Cruz",
#                                                         "reprint": "Y",
#                                                         "role": "author",
#                                                         "seq_no": 6,
#                                                         "wos_standard": "de la Cruz, MO"
#                                                     },
#                                                     {
#                                                         "addr_no": 4,
#                                                         "daisng_id": 30415168,
#                                                         "display_name": "Bedzyk, Michael J.",
#                                                         "first_name": "Michael J.",
#                                                         "full_name": "Bedzyk, Michael J.",
#                                                         "last_name": "Bedzyk",
#                                                         "reprint": "Y",
#                                                         "role": "author",
#                                                         "seq_no": 7,
#                                                         "wos_standard": "Bedzyk, MJ"
#                                                     }
#                                                 ]
#                                             }
#                                         }
#                                     ],
#                                     "count": 4
#                                 },
#                                 "category_info": {
#                                     "headings": {
#                                         "count": 1,
#                                         "heading": "Science & Technology"
#                                     },
#                                     "subheadings": {
#                                         "count": 2,
#                                         "subheading": [
#                                             "Physical Sciences",
#                                             "Technology"
#                                         ]
#                                     },
#                                     "subjects": {
#                                         "count": 7,
#                                         "subject": [
#                                             {
#                                                 "ascatype": "traditional",
#                                                 "content": "Chemistry, Multidisciplinary"
#                                             },
#                                             {
#                                                 "ascatype": "traditional",
#                                                 "content": "Chemistry, Physical"
#                                             },
#                                             {
#                                                 "ascatype": "traditional",
#                                                 "content": "Nanoscience & Nanotechnology"
#                                             },
#                                             {
#                                                 "ascatype": "traditional",
#                                                 "content": "Materials Science, Multidisciplinary"
#                                             },
#                                             {
#                                                 "ascatype": "extended",
#                                                 "content": "Chemistry"
#                                             },
#                                             {
#                                                 "ascatype": "extended",
#                                                 "content": "Science & Technology - Other Topics"
#                                             },
#                                             {
#                                                 "ascatype": "extended",
#                                                 "content": "Materials Science"
#                                             }
#                                         ]
#                                     }
#                                 },
#                                 "fund_ack": {
#                                     "fund_text": {
#                                         "p": "This work was primarily supported by Department of Energy, Office of Science, Basic Energy Sciences under award number DE-SC0018093. C.A.M. acknowledges support for synthesis and characterization of the SNAs from the Vannevar Bush Faculty Fellowship program sponsored by the Basic Research Office of the Assistant Secretary of Defense for Research and Engineering and funded by the Office of Naval Research through grant N00014-15-1-0043. M.O.d.l.C. acknowledges support for computational work from the Sherman Fairchild Foundation. L.M.M. acknowledges support from the National Defense Science and Engineering Graduate fellowship program. Use of the Advanced Photon Source at Argonne National Lab was supported by DOE-BES (DE-AC02-06CH11357). SAXS experiments were performed at the APS DND-CAT SID-D beamline, which is supported through E. I. duPont de Nemours & Co., Northwestern University (NU), The Dow Chemical Co., and the NSF-MRSEC program (DMR-1720139). We thank Dr. Steven Weigand at Sector 5 for help with experimental setup and data reduction. SAXS experiments were also performed at APS Sector 121D-C. We thank Soenke Seifert at Sector 12 for his assistance with the SAXS setup at Sector 121D-C."
#                                     },
#                                     "grants": {
#                                         "count": 10,
#                                         "grant": [
#                                             {
#                                                 "grant_agency": "Department of Energy, Office of Science, Basic Energy Sciences",
#                                                 "grant_ids": {
#                                                     "count": 1,
#                                                     "grant_id": "DE-SC0018093"
#                                                 }
#                                             },
#                                             {
#                                                 "grant_agency": "Basic Research Office of the Assistant Secretary of Defense for Research and Engineering"
#                                             },
#                                             {
#                                                 "grant_agency": "Office of Naval Research",
#                                                 "grant_ids": {
#                                                     "count": 1,
#                                                     "grant_id": "N00014-15-1-0043"
#                                                 }
#                                             },
#                                             {
#                                                 "grant_agency": "Sherman Fairchild Foundation"
#                                             },
#                                             {
#                                                 "grant_agency": "National Defense Science and Engineering Graduate fellowship program"
#                                             },
#                                             {
#                                                 "grant_agency": "DOE-BES",
#                                                 "grant_ids": {
#                                                     "count": 1,
#                                                     "grant_id": "DE-AC02-06CH11357"
#                                                 }
#                                             },
#                                             {
#                                                 "grant_agency": "E. I. duPont de Nemours Co."
#                                             },
#                                             {
#                                                 "grant_agency": "Northwestern University (NU)"
#                                             },
#                                             {
#                                                 "grant_agency": "Dow Chemical Co."
#                                             },
#                                             {
#                                                 "grant_agency": "NSF-MRSEC program",
#                                                 "grant_ids": {
#                                                     "count": 1,
#                                                     "grant_id": "DMR-1720139"
#                                                 }
#                                             }
#                                         ]
#                                     }
#                                 },
#                                 "keywords": {
#                                     "count": 4,
#                                     "keyword": [
#                                         "enzymatic DNA degradation",
#                                         "small-angle X-ray scattering DNA-coated proteins",
#                                         "molecular dynamics simulations",
#                                         "counterion distribution"
#                                     ]
#                                 },
#                                 "languages": {
#                                     "count": 1,
#                                     "language": {
#                                         "content": "English",
#                                         "type": "primary"
#                                     }
#                                 },
#                                 "normalized_doctypes": {
#                                     "count": 1,
#                                     "doctype": "Article"
#                                 },
#                                 "normalized_languages": {
#                                     "count": 1,
#                                     "language": {
#                                         "content": "English",
#                                         "type": "primary"
#                                     }
#                                 },
#                                 "refs": {
#                                     "count": 51
#                                 },
#                                 "reprint_addresses": {
#                                     "address_name": [
#                                         {
#                                             "address_spec": {
#                                                 "addr_no": 1,
#                                                 "city": "Evanston",
#                                                 "country": "USA",
#                                                 "full_address": "Northwestern Univ, Appl Phys Program, Evanston, IL 60208 USA",
#                                                 "organizations": {
#                                                     "count": 2,
#                                                     "organization": [
#                                                         "Northwestern Univ",
#                                                         {
#                                                             "content": "Northwestern University",
#                                                             "pref": "Y"
#                                                         }
#                                                     ]
#                                                 },
#                                                 "state": "IL",
#                                                 "suborganizations": {
#                                                     "count": 1,
#                                                     "suborganization": "Appl Phys Program"
#                                                 },
#                                                 "zip": {
#                                                     "content": 60208,
#                                                     "location": "AP"
#                                                 }
#                                             },
#                                             "names": {
#                                                 "count": 2,
#                                                 "name": [
#                                                     {
#                                                         "addr_no": 1,
#                                                         "display_name": "de la Cruz, Monica Olvera",
#                                                         "first_name": "Monica Olvera",
#                                                         "full_name": "de la Cruz, Monica Olvera",
#                                                         "last_name": "de la Cruz",
#                                                         "reprint": "Y",
#                                                         "role": "author",
#                                                         "seq_no": 2,
#                                                         "wos_standard": "de la Cruz, MO"
#                                                     },
#                                                     {
#                                                         "addr_no": 1,
#                                                         "display_name": "Bedzyk, Michael J.",
#                                                         "first_name": "Michael J.",
#                                                         "full_name": "Bedzyk, Michael J.",
#                                                         "last_name": "Bedzyk",
#                                                         "reprint": "Y",
#                                                         "role": "author",
#                                                         "seq_no": 3,
#                                                         "wos_standard": "Bedzyk, MJ"
#                                                     }
#                                                 ]
#                                             }
#                                         },
#                                         {
#                                             "address_spec": {
#                                                 "addr_no": 2,
#                                                 "city": "Evanston",
#                                                 "country": "USA",
#                                                 "full_address": "Northwestern Univ, Dept Mat Sci & Engn, Evanston, IL 60208 USA",
#                                                 "organizations": {
#                                                     "count": 2,
#                                                     "organization": [
#                                                         "Northwestern Univ",
#                                                         {
#                                                             "content": "Northwestern University",
#                                                             "pref": "Y"
#                                                         }
#                                                     ]
#                                                 },
#                                                 "state": "IL",
#                                                 "suborganizations": {
#                                                     "count": 1,
#                                                     "suborganization": "Dept Mat Sci & Engn"
#                                                 },
#                                                 "zip": {
#                                                     "content": 60208,
#                                                     "location": "AP"
#                                                 }
#                                             },
#                                             "names": {
#                                                 "count": 3,
#                                                 "name": [
#                                                     {
#                                                         "addr_no": 2,
#                                                         "display_name": "Mirkin, Chad A.",
#                                                         "first_name": "Chad A.",
#                                                         "full_name": "Mirkin, Chad A.",
#                                                         "last_name": "Mirkin",
#                                                         "reprint": "Y",
#                                                         "role": "author",
#                                                         "seq_no": 1,
#                                                         "wos_standard": "Mirkin, CA"
#                                                     },
#                                                     {
#                                                         "addr_no": 2,
#                                                         "display_name": "de la Cruz, Monica Olvera",
#                                                         "first_name": "Monica Olvera",
#                                                         "full_name": "de la Cruz, Monica Olvera",
#                                                         "last_name": "de la Cruz",
#                                                         "reprint": "Y",
#                                                         "role": "author",
#                                                         "seq_no": 2,
#                                                         "wos_standard": "de la Cruz, MO"
#                                                     },
#                                                     {
#                                                         "addr_no": 2,
#                                                         "display_name": "Bedzyk, Michael J.",
#                                                         "first_name": "Michael J.",
#                                                         "full_name": "Bedzyk, Michael J.",
#                                                         "last_name": "Bedzyk",
#                                                         "reprint": "Y",
#                                                         "role": "author",
#                                                         "seq_no": 3,
#                                                         "wos_standard": "Bedzyk, MJ"
#                                                     }
#                                                 ]
#                                             }
#                                         },
#                                         {
#                                             "address_spec": {
#                                                 "addr_no": 3,
#                                                 "city": "Evanston",
#                                                 "country": "USA",
#                                                 "full_address": "Northwestern Univ, Dept Chem, Evanston, IL 60208 USA",
#                                                 "organizations": {
#                                                     "count": 2,
#                                                     "organization": [
#                                                         "Northwestern Univ",
#                                                         {
#                                                             "content": "Northwestern University",
#                                                             "pref": "Y"
#                                                         }
#                                                     ]
#                                                 },
#                                                 "state": "IL",
#                                                 "suborganizations": {
#                                                     "count": 1,
#                                                     "suborganization": "Dept Chem"
#                                                 },
#                                                 "zip": {
#                                                     "content": 60208,
#                                                     "location": "AP"
#                                                 }
#                                             },
#                                             "names": {
#                                                 "count": 2,
#                                                 "name": [
#                                                     {
#                                                         "addr_no": 3,
#                                                         "display_name": "Mirkin, Chad A.",
#                                                         "first_name": "Chad A.",
#                                                         "full_name": "Mirkin, Chad A.",
#                                                         "last_name": "Mirkin",
#                                                         "reprint": "Y",
#                                                         "role": "author",
#                                                         "seq_no": 1,
#                                                         "wos_standard": "Mirkin, CA"
#                                                     },
#                                                     {
#                                                         "addr_no": 3,
#                                                         "display_name": "de la Cruz, Monica Olvera",
#                                                         "first_name": "Monica Olvera",
#                                                         "full_name": "de la Cruz, Monica Olvera",
#                                                         "last_name": "de la Cruz",
#                                                         "reprint": "Y",
#                                                         "role": "author",
#                                                         "seq_no": 2,
#                                                         "wos_standard": "de la Cruz, MO"
#                                                     }
#                                                 ]
#                                             }
#                                         },
#                                         {
#                                             "address_spec": {
#                                                 "addr_no": 4,
#                                                 "city": "Evanston",
#                                                 "country": "USA",
#                                                 "full_address": "Northwestern Univ, Dept Phys & Astron, Evanston, IL 60208 USA",
#                                                 "organizations": {
#                                                     "count": 2,
#                                                     "organization": [
#                                                         "Northwestern Univ",
#                                                         {
#                                                             "content": "Northwestern University",
#                                                             "pref": "Y"
#                                                         }
#                                                     ]
#                                                 },
#                                                 "state": "IL",
#                                                 "suborganizations": {
#                                                     "count": 1,
#                                                     "suborganization": "Dept Phys & Astron"
#                                                 },
#                                                 "zip": {
#                                                     "content": 60208,
#                                                     "location": "AP"
#                                                 }
#                                             },
#                                             "names": {
#                                                 "count": 2,
#                                                 "name": [
#                                                     {
#                                                         "addr_no": 4,
#                                                         "display_name": "de la Cruz, Monica Olvera",
#                                                         "first_name": "Monica Olvera",
#                                                         "full_name": "de la Cruz, Monica Olvera",
#                                                         "last_name": "de la Cruz",
#                                                         "reprint": "Y",
#                                                         "role": "author",
#                                                         "seq_no": 2,
#                                                         "wos_standard": "de la Cruz, MO"
#                                                     },
#                                                     {
#                                                         "addr_no": 4,
#                                                         "display_name": "Bedzyk, Michael J.",
#                                                         "first_name": "Michael J.",
#                                                         "full_name": "Bedzyk, Michael J.",
#                                                         "last_name": "Bedzyk",
#                                                         "reprint": "Y",
#                                                         "role": "author",
#                                                         "seq_no": 3,
#                                                         "wos_standard": "Bedzyk, MJ"
#                                                     }
#                                                 ]
#                                             }
#                                         }
#                                     ],
#                                     "count": 4
#                                 }
#                             },
#                             "item": {
#                                 "bib_id": "13 (10): 11382-11391 OCT 2019",
#                                 "bib_pagecount": {
#                                     "content": 1446,
#                                     "type": "Journal"
#                                 },
#                                 "coll_id": "WOS",
#                                 "ids": {
#                                     "avail": "N",
#                                     "content": "JH5IF"
#                                 },
#                                 "keywords_plus": {
#                                     "count": 10,
#                                     "keyword": [
#                                         "INTRACELLULAR DELIVERY",
#                                         "MECHANISM",
#                                         "STABILITY",
#                                         "NANOPARTICLES",
#                                         "SPECIFICITY",
#                                         "ACTIVATION",
#                                         "NUCLEASES",
#                                         "PROTEINS",
#                                         "BINDING",
#                                         "SAXS"
#                                     ]
#                                 },
#                                 "xmlns:xsi": "http://www.w3.org/2001/XMLSchema-instance",
#                                 "xsi:type": "itemType_wos"
#                             },
#                             "summary": {
#                                 "EWUID": {
#                                     "WUID": {
#                                         "coll_id": "WOS"
#                                     },
#                                     "edition": {
#                                         "value": "WOS.SCI"
#                                     }
#                                 },
#                                 "doctypes": {
#                                     "count": 1,
#                                     "doctype": "Article"
#                                 },
#                                 "names": {
#                                     "count": 7,
#                                     "name": [
#                                         {
#                                             "addr_no": 1,
#                                             "daisng_id": 22345515,
#                                             "display_name": "Krishnamoorthy, Kurinji",
#                                             "first_name": "Kurinji",
#                                             "full_name": "Krishnamoorthy, Kurinji",
#                                             "last_name": "Krishnamoorthy",
#                                             "role": "author",
#                                             "seq_no": 1,
#                                             "wos_standard": "Krishnamoorthy, K"
#                                         },
#                                         {
#                                             "addr_no": 2,
#                                             "daisng_id": 1159545,
#                                             "display_name": "Kewalramani, Sumit",
#                                             "first_name": "Sumit",
#                                             "full_name": "Kewalramani, Sumit",
#                                             "last_name": "Kewalramani",
#                                             "role": "author",
#                                             "seq_no": 2,
#                                             "wos_standard": "Kewalramani, S"
#                                         },
#                                         {
#                                             "addr_no": 1,
#                                             "daisng_id": 31118905,
#                                             "display_name": "Ehlen, Ali",
#                                             "first_name": "Ali",
#                                             "full_name": "Ehlen, Ali",
#                                             "last_name": "Ehlen",
#                                             "role": "author",
#                                             "seq_no": 3,
#                                             "wos_standard": "Ehlen, A"
#                                         },
#                                         {
#                                             "addr_no": 2,
#                                             "daisng_id": 4419377,
#                                             "display_name": "Moreau, Liane M.",
#                                             "first_name": "Liane M.",
#                                             "full_name": "Moreau, Liane M.",
#                                             "last_name": "Moreau",
#                                             "role": "author",
#                                             "seq_no": 4,
#                                             "wos_standard": "Moreau, LM"
#                                         },
#                                         {
#                                             "addr_no": "2 3",
#                                             "daisng_id": 31444953,
#                                             "display_name": "Mirkin, Chad A.",
#                                             "first_name": "Chad A.",
#                                             "full_name": "Mirkin, Chad A.",
#                                             "last_name": "Mirkin",
#                                             "reprint": "Y",
#                                             "role": "author",
#                                             "seq_no": 5,
#                                             "wos_standard": "Mirkin, CA"
#                                         },
#                                         {
#                                             "addr_no": "1 2 3 4",
#                                             "daisng_id": 31445516,
#                                             "display_name": "de la Cruz, Monica Olvera",
#                                             "first_name": "Monica Olvera",
#                                             "full_name": "de la Cruz, Monica Olvera",
#                                             "last_name": "de la Cruz",
#                                             "reprint": "Y",
#                                             "role": "author",
#                                             "seq_no": 6,
#                                             "wos_standard": "de la Cruz, MO"
#                                         },
#                                         {
#                                             "addr_no": "1 2 4",
#                                             "daisng_id": 30415168,
#                                             "display_name": "Bedzyk, Michael J.",
#                                             "first_name": "Michael J.",
#                                             "full_name": "Bedzyk, Michael J.",
#                                             "last_name": "Bedzyk",
#                                             "reprint": "Y",
#                                             "role": "author",
#                                             "seq_no": 7,
#                                             "wos_standard": "Bedzyk, MJ"
#                                         }
#                                     ]
#                                 },
#                                 "pub_info": {
#                                     "coverdate": "OCT 2019",
#                                     "has_abstract": "Y",
#                                     "issue": 10,
#                                     "page": {
#                                         "begin": 11382,
#                                         "content": "11382-11391",
#                                         "end": 11391,
#                                         "page_count": 10
#                                     },
#                                     "pubmonth": "OCT",
#                                     "pubtype": "Journal",
#                                     "pubyear": 2019,
#                                     "sortdate": "2019-10-01",
#                                     "vol": 13
#                                 },
#                                 "publishers": {
#                                     "publisher": {
#                                         "address_spec": {
#                                             "addr_no": 1,
#                                             "city": "WASHINGTON",
#                                             "full_address": "1155 16TH ST, NW, WASHINGTON, DC 20036 USA"
#                                         },
#                                         "names": {
#                                             "count": 1,
#                                             "name": {
#                                                 "addr_no": 1,
#                                                 "display_name": "AMER CHEMICAL SOC",
#                                                 "full_name": "AMER CHEMICAL SOC",
#                                                 "role": "publisher",
#                                                 "seq_no": 1
#                                             }
#                                         }
#                                     }
#                                 },
#                                 "titles": {
#                                     "count": 6,
#                                     "title": [
#                                         {
#                                             "content": "ACS NANO",
#                                             "type": "source"
#                                         },
#                                         {
#                                             "content": "ACS NANO",
#                                             "type": "source_abbrev"
#                                         },
#                                         {
#                                             "content": "ACS Nano",
#                                             "type": "abbrev_iso"
#                                         },
#                                         {
#                                             "content": "ACS NANO",
#                                             "type": "abbrev_11"
#                                         },
#                                         {
#                                             "content": "ACS NANO",
#                                             "type": "abbrev_29"
#                                         },
#                                         {
#                                             "content": "Enzymatic Degradation of DNA Probed by In Situ X-ray Scattering",
#                                             "type": "item"
#                                         }
#                                     ]
#                                 }
#                             }
#                         }
#                     }
#                 ]
#             }
#         }
#     },
#     "QueryResult": {
#         "QueryID": 2,
#         "RecordsFound": 1,
#         "RecordsSearched": 76092267
#     }
# }

# %%
# Out:
# response received
