# %%
# Dependencies
import requests
import json
import pandas as pd
import numpy as np
import re
import io
from config import api_key
from collections import OrderedDict
from pandas.io.json import json_normalize

# %%
# Create a reference to the CSV and import it into a Pandas DataFrame
csv_path = "WOS_test.csv"
WOS_df = pd.read_csv(csv_path)
WOS_df.head()
# Out:
#   PT                                                 AU  BA  BE  GP  \
# 0  J                                        Stevens, WW NaN NaN NaN
# 1  J  Rugg, BK; Krzyaniak, MD; Phelan, BT; Ratner, M... NaN NaN NaN
# 2  J  He, Q; Arroyo, ED; Smukowski, SN; Xu, J; Pioch... NaN NaN NaN
# 3  J  Case, DJ; Liu, YF; Kiss, IZ; Angilella, JR; Mo... NaN NaN NaN
# 4  J  Leebens-Mack, JH; Barker, MS; Carpenter, EJ; D... NaN NaN NaN
#
#                                                   AF  BF  \
# 0                                Stevens, Whitney W. NaN
# 1  Rugg, Brandon K.; Krzyaniak, Matthew D.; Phela... NaN
# 2  He, Qionger; Arroyo, Erica D.; Smukowski, Samu... NaN
# 3  Case, Daniel J.; Liu, Yifan; Kiss, Istvan Z.; ... NaN
# 4  Leebens-Mack, James H.; Barker, Michael S.; Ca... NaN
#
#                                   CA  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4  One Thousand Plant Transcriptomes
#
#                                                   TI                    SO  \
# 0  A new treatment for chronic rhinosinusitis wit...                LANCET
# 1  Photodriven quantum teleportation of an electr...      NATURE CHEMISTRY
# 2  Critical period inhibition of NKCC1 rectifies ...  MOLECULAR PSYCHIATRY
# 3  Braess's paradox and programmable behaviour in...                NATURE
# 4  One thousand plant transcriptomes and the phyl...                NATURE
#
#    ...  PG                                                 WC  \
# 0  ...   3                       Medicine, General & Internal
# 1  ...   6                       Chemistry, Multidisciplinary
# 2  ...  16  Biochemistry & Molecular Biology; Neuroscience...
# 3  ...   9                         Multidisciplinary Sciences
# 4  ...  17                         Multidisciplinary Sciences
#
#                                                   SC     GA  \
# 0                        General & Internal Medicine  JI8SM
# 1                                          Chemistry  JI2WN
# 2  Biochemistry & Molecular Biology; Neuroscience...  JH3PD
# 3                Science & Technology - Other Topics  JI9UH
# 4                Science & Technology - Other Topics  JI9UH
#
#                     UT        PM                               OA  HC  HP  \
# 0  WOS:000493733600007  31543427                              NaN NaN NaN
# 1  WOS:000493326400006  31548665                              NaN NaN NaN
# 2  WOS:000492678900016  29703945  Green Accepted, Green Published NaN NaN
# 3  WOS:000493807800037  31645762                              NaN NaN NaN
# 4  WOS:000493807800044  31645766  Green Published, Green Accepted NaN NaN
#
#            DA
# 0  11/14/2019
# 1  11/14/2019
# 2  11/14/2019
# 3  11/14/2019
# 4  11/14/2019
#
# [5 rows x 67 columns]

# %%
#https://clarivate.com/webofsciencegroup/solutions/xml-and-apis/
#https://developer.clarivate.com/help
#https://api.clarivate.com/api/incites/DocumentLevelMetricsByUT/json

url = "https://api.clarivate.com/api/incites/DocumentLevelMetricsByUT/json"

headers = {
     'X-ApiKey': api_key,
     'Accept':'application/json'
}



parameters = {
    "UT": "000492801600048"
   
}

response = requests.get(url, headers=headers, params=parameters)


print(response.url)
print(response.status_code)

response_json = response.json()
print(json.dumps(response_json, indent=4, sort_keys=True))
# Out:
# https://api.clarivate.com/api/incites/DocumentLevelMetricsByUT/json?UT=000492801600048
# 200
# {
#     "api": [
#         {
#             "name": "IncitesWebServices.getDocumentLevelMetricsByUT",
#             "rval": [
#                 {
#                     "ARTICLE_TYPE": "AA",
#                     "AVG_EXPECTED_RATE": "1.0407",
#                     "ESI_MOST_CITED_ARTICLE": "0",
#                     "HOT_PAPER": "0",
#                     "IMPACT_FACTOR": "13.903",
#                     "ISI_LOC": "000492801600048",
#                     "IS_INDUSTRY_COLLAB": "0",
#                     "IS_INSTITUTION_COLLAB": "0",
#                     "IS_INTERNATIONAL_COLLAB": "0",
#                     "JOURNAL_ACT_EXP_CITATIONS": "0.0",
#                     "JOURNAL_EXPECTED_CITATIONS": "1.831135",
#                     "NCI": "0.0",
#                     "OA_FLAG": "0",
#                     "PERCENTILE": "100.0",
#                     "TOT_CITES": "0"
#                 }
#             ]
#         }
#     ]
# }
